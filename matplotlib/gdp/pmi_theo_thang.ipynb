# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
encoding_list = ['ascii', 'big5', 'big5hkscs', 'cp037', 'cp273', 'cp424', 'cp437', 'cp500', 'cp720', 'cp737'
                 , 'cp775', 'cp850', 'cp852', 'cp855', 'cp856', 'cp857', 'cp858', 'cp860', 'cp861', 'cp862'
                 , 'cp863', 'cp864', 'cp865', 'cp866', 'cp869', 'cp874', 'cp875', 'cp932', 'cp949', 'cp950'
                 , 'cp1006', 'cp1026', 'cp1125', 'cp1140', 'cp1250', 'cp1251', 'cp1252', 'cp1253', 'cp1254'
                 , 'cp1255', 'cp1256', 'cp1257', 'cp1258', 'euc_jp', 'euc_jis_2004', 'euc_jisx0213', 'euc_kr'
                 , 'gb2312', 'gbk', 'gb18030', 'hz', 'iso2022_jp', 'iso2022_jp_1', 'iso2022_jp_2'
                 , 'iso2022_jp_2004', 'iso2022_jp_3', 'iso2022_jp_ext', 'iso2022_kr', 'latin_1', 'iso8859_2'
                 , 'iso8859_3', 'iso8859_4', 'iso8859_5', 'iso8859_6', 'iso8859_7', 'iso8859_8', 'iso8859_9'
                 , 'iso8859_10', 'iso8859_11', 'iso8859_13', 'iso8859_14', 'iso8859_15', 'iso8859_16', 'johab'
                 , 'koi8_r', 'koi8_t', 'koi8_u', 'kz1048', 'mac_cyrillic', 'mac_greek', 'mac_iceland', 'mac_latin2'
                 , 'mac_roman', 'mac_turkish', 'ptcp154', 'shift_jis', 'shift_jis_2004', 'shift_jisx0213', 'utf_32'
                 , 'utf_32_be', 'utf_32_le', 'utf_16', 'utf_16_be', 'utf_16_le', 'utf_7', 'utf_8', 'utf_8_sig']

pmi_theo_thang = ''
for encoding in encoding_list:
    worked = True
    try:
        pmi_theo_thang = pd.read_csv('pmi_theo_thang.csv', encoding=encoding, sep='\t')
    except:
        worked = False

# %%
pmi_theo_thang.columns
# Out:
# Index(['Unnamed: 0', 'T12 2020', 'T1 2021', 'T2 2021', 'T3 2021', 'T4 2021',
#        'T5 2021', 'T6 2021', 'T7 2021', 'T8 2021', 'T9 2021', 'T10 2021',
#        'T11 2021 ', 'T12 2021', 'T1 2022', 'T2 2022', 'T3 2022', 'T4 2022',
#        'T5 2022', 'T6 2022', 'T7 2022', 'T8 2022', 'T9 2022', 'T10 2022',
#        'T11 2022', 'T12 2022', 'T1 2023', 'T2 2023', 'T3 2023', 'T4 2023',
#        'T5 2023', 'T6 2023', 'T7 2023', 'T8 2023', 'T9 2023', 'T10 2023',
#        'T11 2023', 'T12 2023', 'T1 2024', 'T2 2024', 'T3 2024'],
#       dtype='object')

# %%
pmi_theo_thang = pmi_theo_thang.drop(columns=['Unnamed: 0'], axis=1)
pmi_theo_thang
# Out:
#    T12 2020  T1 2021  T2 2021  T3 2021  T4 2021  T5 2021  T6 2021  T7 2021  \
# 0      51.7     51.3     51.6     53.6     54.7     53.1     44.1     45.1
#
#    T8 2021  T9 2021  ...  T6 2023  T7 2023  T8 2023  T9 2023  T10 2023  \
# 0     40.2     40.2  ...     46.2     48.7     50.5     49.7      49.6
#
#    T11 2023  T12 2023  T1 2024  T2 2024  T3 2024
# 0      47.3      48.9     50.3     50.4     49.9
#
# [1 rows x 40 columns]

# %%
columns = pmi_theo_thang.columns
columns
# Out:
# Index(['T12 2020', 'T1 2021', 'T2 2021', 'T3 2021', 'T4 2021', 'T5 2021',
#        'T6 2021', 'T7 2021', 'T8 2021', 'T9 2021', 'T10 2021', 'T11 2021 ',
#        'T12 2021', 'T1 2022', 'T2 2022', 'T3 2022', 'T4 2022', 'T5 2022',
#        'T6 2022', 'T7 2022', 'T8 2022', 'T9 2022', 'T10 2022', 'T11 2022',
#        'T12 2022', 'T1 2023', 'T2 2023', 'T3 2023', 'T4 2023', 'T5 2023',
#        'T6 2023', 'T7 2023', 'T8 2023', 'T9 2023', 'T10 2023', 'T11 2023',
#        'T12 2023', 'T1 2024', 'T2 2024', 'T3 2024'],
#       dtype='object')

# %%
_pmi_theo_thang = pmi_theo_thang.iloc[0:1, :].values.tolist()[0]
_pmi_theo_thang
# Out:
# [51.7,
#  51.3,
#  51.6,
#  53.6,
#  54.7,
#  53.1,
#  44.1,
#  45.1,
#  40.2,
#  40.2,
#  52.1,
#  52.2,
#  52.5,
#  53.7,
#  54.3,
#  51.7,
#  51.7,
#  54.7,
#  54.0,
#  51.2,
#  52.7,
#  52.5,
#  50.6,
#  47.4,
#  46.4,
#  47.4,
#  51.2,
#  47.7,
#  46.7,
#  45.3,
#  46.2,
#  48.7,
#  50.5,
#  49.7,
#  49.6,
#  47.3,
#  48.9,
#  50.3,
#  50.4,
#  49.9]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(columns, _pmi_theo_thang, marker='o', color='#16058b', linestyle='-')

for i, value in enumerate(_pmi_theo_thang):
    offset = 0.2 if value > 0 else -0.5
    ax.text(i, value + offset, f"{value:,}", ha='center', va='bottom', fontsize=10)

ax.yaxis.set_major_locator(plt.MultipleLocator(1))

def y_formatter(x, pos):
    return f'{int(x):,}'

ax.yaxis.set_major_formatter(ticker.FuncFormatter(y_formatter))

ax.annotate('PMI', xy=(0, 1), xytext=(0, 5),
            xycoords='axes fraction', textcoords='offset points',
            ha='center', va='bottom', fontsize=20, color='#0066ff')

ax.annotate('Quý', xy=(1, 0), xytext=(0, -20),
            xycoords='axes fraction', textcoords='offset points',
            ha='center', va='bottom', fontsize=12, color='black')

plt.xticks(ha='center', rotation=45)
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', linewidth=0.5, color='gray')
plt.legend(['PMI'], loc='upper right', fontsize=12)
plt.show()
