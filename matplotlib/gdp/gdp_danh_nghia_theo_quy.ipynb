# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
encoding_list = ['ascii', 'big5', 'big5hkscs', 'cp037', 'cp273', 'cp424', 'cp437', 'cp500', 'cp720', 'cp737'
                 , 'cp775', 'cp850', 'cp852', 'cp855', 'cp856', 'cp857', 'cp858', 'cp860', 'cp861', 'cp862'
                 , 'cp863', 'cp864', 'cp865', 'cp866', 'cp869', 'cp874', 'cp875', 'cp932', 'cp949', 'cp950'
                 , 'cp1006', 'cp1026', 'cp1125', 'cp1140', 'cp1250', 'cp1251', 'cp1252', 'cp1253', 'cp1254'
                 , 'cp1255', 'cp1256', 'cp1257', 'cp1258', 'euc_jp', 'euc_jis_2004', 'euc_jisx0213', 'euc_kr'
                 , 'gb2312', 'gbk', 'gb18030', 'hz', 'iso2022_jp', 'iso2022_jp_1', 'iso2022_jp_2'
                 , 'iso2022_jp_2004', 'iso2022_jp_3', 'iso2022_jp_ext', 'iso2022_kr', 'latin_1', 'iso8859_2'
                 , 'iso8859_3', 'iso8859_4', 'iso8859_5', 'iso8859_6', 'iso8859_7', 'iso8859_8', 'iso8859_9'
                 , 'iso8859_10', 'iso8859_11', 'iso8859_13', 'iso8859_14', 'iso8859_15', 'iso8859_16', 'johab'
                 , 'koi8_r', 'koi8_t', 'koi8_u', 'kz1048', 'mac_cyrillic', 'mac_greek', 'mac_iceland', 'mac_latin2'
                 , 'mac_roman', 'mac_turkish', 'ptcp154', 'shift_jis', 'shift_jis_2004', 'shift_jisx0213', 'utf_32'
                 , 'utf_32_be', 'utf_32_le', 'utf_16', 'utf_16_be', 'utf_16_le', 'utf_7', 'utf_8', 'utf_8_sig']

gdp_danh_nghia_theo_quy = ''
for encoding in encoding_list:
    worked = True
    try:
        gdp_danh_nghia_theo_quy = pd.read_csv('gdp_danh_nghia_theo_quy.csv', encoding=encoding, sep='\t')
    except:
        worked = False

# %%
gdp_danh_nghia_theo_quy.columns
# Out:
# Index(['Unnamed: 0', 'Q1 2015', 'Q2 2015', 'Q3 2015', 'Q4 2015', 'Q1 2016',
#        'Q2 2016', 'Q3 2016', 'Q4 2016', 'Q1 2017', 'Q2 2017', 'Q3 2017',
#        'Q4 2017', 'Q1 2018', 'Q2 2018', 'Q3 2018', 'Q4 2018', 'Q1 2019',
#        'Q2 2019', 'Q3 2019', 'Q4 2019', 'Q1 2020', 'Q2 2020', 'Q3 2020',
#        'Q4 2020', 'Q1 2021', 'Q2 2021', 'Q3 2021', 'Q4 2021', 'Q1 2022',
#        'Q2 2022', 'Q3 2022', 'Q4 2022', 'Q1 2023', 'Q2 2023', 'Q3 2023',
#        'Q4 2023', 'Q1 2024'],
#       dtype='object')

# %%
gdp_danh_nghia_theo_quy = gdp_danh_nghia_theo_quy.drop(columns=['Unnamed: 0'], axis=1)
gdp_danh_nghia_theo_quy
# Out:
#     Q1 2015  Q2 2015    Q3 2015    Q4 2015  Q1 2016    Q2 2016    Q3 2016  \
# 0   809,613  970,388  1,072,330  4,192,862  850,461  1,031,489  1,158,096
# 1    99,978  197,315    167,607    712,460   97,163    198,727    175,956
# 2    71,249  156,728    120,496    533,615   68,265    157,708    126,439
# 3     5,674    6,731      8,174     30,934    6,204      7,335      8,965
# 4    23,055   33,856     38,937    147,911   22,694     33,683     40,551
# 5   245,643  264,473    292,424  1,166,028  253,136    273,362    305,734
# 6   119,580  143,027    145,819    574,201  129,192    159,421    164,829
# 7    33,638   34,707     40,576    167,402   39,729     38,986     44,929
# 8    92,426   86,739    106,029    424,425   84,215     74,954     95,975
# 9    36,905   49,579     56,119    228,102   39,169     54,885     62,381
# 10  341,210  363,201    450,175  1,665,962  370,286    401,340    498,240
# 11   89,737   86,934    108,226    425,543   97,694     96,553    120,248
# ...

# %%
columns = gdp_danh_nghia_theo_quy.columns
columns
# Out:
# Index(['Q1 2015', 'Q2 2015', 'Q3 2015', 'Q4 2015', 'Q1 2016', 'Q2 2016',
#        'Q3 2016', 'Q4 2016', 'Q1 2017', 'Q2 2017', 'Q3 2017', 'Q4 2017',
#        'Q1 2018', 'Q2 2018', 'Q3 2018', 'Q4 2018', 'Q1 2019', 'Q2 2019',
#        'Q3 2019', 'Q4 2019', 'Q1 2020', 'Q2 2020', 'Q3 2020', 'Q4 2020',
#        'Q1 2021', 'Q2 2021', 'Q3 2021', 'Q4 2021', 'Q1 2022', 'Q2 2022',
#        'Q3 2022', 'Q4 2022', 'Q1 2023', 'Q2 2023', 'Q3 2023', 'Q4 2023',
#        'Q1 2024'],
#       dtype='object')

# %%
gdp_danh_nghia = gdp_danh_nghia_theo_quy.iloc[0:1, :].values.tolist()[0]
gdp_danh_nghia
# Out:
# ['809,613',
#  '970,388',
#  '1,072,330',
#  '4,192,862',
#  '850,461',
#  '1,031,489',
#  '1,158,096',
#  '1,462,686',
#  '931,831',
#  '1,129,088',
#  '1,270,212',
#  '1,674,845',
#  '1,028,618',
#  '1,242,437',
#  '1,412,285',
#  '1,858,992',
#  '1,118,019',
#  '1,367,132',
#  '1,541,310',
#  '2,010,887',
#  '1,193,485',
#  '1,382,951',
#  '1,593,586',
#  '2,121,415',
#  '1,953,117',
#  '2,050,431',
#  '1,986,949',
#  '2,399,005',
#  '2,132,796',
#  '2,292,012',
#  '2,373,152',
#  '2,669,131',
#  '2,300,882',
#  '2,444,649',
#  '2,540,588',
#  '2,921,187',
#  '2,513,091']

# %%
_gdp_danh_nghia = [int(x.replace(',', '')) for x in gdp_danh_nghia]
fig, ax = plt.subplots(figsize=(20, 10))
bars = ax.bar(columns, _gdp_danh_nghia, color='#0066ff')

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2 , yval + 15000, f"{yval:,}", ha='center', va='bottom', fontsize=10)

ax.yaxis.set_major_locator(plt.MultipleLocator(100000))

def y_formatter(x, pos):
    return f'{int(x):,}'

ax.yaxis.set_major_formatter(ticker.FuncFormatter(y_formatter))

ax.annotate('Tỷ đồng', xy=(0, 1), xytext=(0, 10),
            xycoords='axes fraction', textcoords='offset points',
            ha='center', va='bottom', fontsize=12, color='black')

ax.annotate('Quý', xy=(1, 0), xytext=(0, -20),
            xycoords='axes fraction', textcoords='offset points',
            ha='center', va='bottom', fontsize=12, color='black')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', linewidth=0.5, color='black')
circle_marker = plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='#0066ff', markersize=10, label='GDP danh nghĩa')
ax.legend(handles=[circle_marker], loc='upper left')
plt.show()
